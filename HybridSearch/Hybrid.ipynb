# %%
# !pip install --upgrade --quiet pinecone-client pinecone-text pinecone-notebooks pinecone

# %%
api_key = ""

# %%
from langchain_community.retrievers import PineconeHybridSearchRetriever
import os
from pinecone import Pinecone,ServerlessSpec
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from langchain_community.retrievers import PineconeHybridSearchRetriever
#       2 import os
#       3 from pinecone import Pinecone,ServerlessSpec
#
# File c:\Users\omema\anaconda3\envs\myenv\lib\site-packages\langchain_community\retrievers\__init__.py:199, in __getattr__(name)
#     197 def __getattr__(name: str) -> Any:
#     198     if name in _module_lookup:
# --> 199         module = importlib.import_module(_module_lookup[name])
#     200         return getattr(module, name)
#     201     raise AttributeError(f"module {__name__} has no attribute {name}")
#
# File c:\Users\omema\anaconda3\envs\myenv\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\omema\anaconda3\envs\myenv\lib\site-packages\langchain_community\retrievers\pinecone_hybrid_search.py:10
#       8 from langchain_core.embeddings import Embeddings
#       9 from langchain_core.retrievers import BaseRetriever
# ---> 10 from langchain_core.utils import pre_init
#      11 from pydantic import ConfigDict
#      14 def hash_text(text: str) -> str:
#
# ImportError: cannot import name 'pre_init' from 'langchain_core.utils' (c:\Users\omema\anaconda3\envs\myenv\lib\site-packages\langchain_core\utils\__init__.py)
